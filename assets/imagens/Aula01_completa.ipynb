# %% [markdown]
# # Módulo 1

# %% [markdown]
# Começando a Aula de Python

# %%
5
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %% [markdown]
# Textos ou palavras são chamados de string

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %%
print('Olá mundo')
# Out:
# Olá mundo

# %%
print("Olá mundo " + "5")
# Out:
# Olá mundo 5

# %%
5 + 2
# Out:
# 7

# %%
print(5 + 2)
# Out:
# 7

# %%
produto1 = 5

# %%
print(produto1)
# Out:
# 5

# %%
produto2 = 2000

# %%
print(produto2)
# Out:
# 2000

# %%
produto3 = 1

# %%
print(produto1 + produto2 + produto3)
# Out:
# 2006

# %%
nome_do_produto1 = "Macarrão"
nome_do_produto2 = "Celular"
nome_do_produto3 = "Bala"

# %%
print(nome_do_produto1 + " " + nome_do_produto2 + " " + nome_do_produto3)
# Out:
# Macarrão Celular Bala

# %%
amigos = 5
aluguel = 1000
supermercado = 500
carro = 400

# %%
total = aluguel + supermercado + carro

# %%
print(total)
# Out:
# 1900

# %%
aluguel = 900
total = aluguel + supermercado + carro

# %%
print(total)
# Out:
# 1800

# %%
aluguel = aluguel - 100

# %%
print(aluguel)
# Out:
# 800

# %%
amigos = 6
aluguel = 1000
supermercado = 500
carro = 400

# %%
print(amigos)
# Out:
# 6

# %%
print(carro * 2)
# Out:
# 800

# %%
total_de_carros = carro * 2

# %%
print(total_de_carros)
# Out:
# 800

# %%
total = aluguel + supermercado + total_de_carros
print(total)
# Out:
# 2300

# %%
total_por_pessoa = total / amigos
print(total_por_pessoa)
# Out:
# 383.3333333333333

# %%
type(aluguel)
# Out:
# int

# %%
type(total_por_pessoa)
# Out:
# float

# %%
type(nome_do_produto1)
# Out:
# str

# %%
pedro_tem_carteira_de_motorista = True
mario_tem_carteira_de_motorista = False

# %%
type(mario_tem_carteira_de_motorista)
# Out:
# bool

# %% [markdown]
# Inicial: "   Fabrício CARRaro   da alura   "<br>
# Final: "FABRÍCIO CARRARO DA ALURA"

# %%
texto = "   Fabrício CARRaro  da alura   "

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
print(texto.lower())
# Out:
#    fabrício carraro  da alura

# %%
print(texto.upper())
# Out:
#    FABRÍCIO CARRARO  DA ALURA

# %%
print(texto.strip())
# Out:
# Fabrício CARRaro  da alura

# %%
print(texto.replace("  ", " "))
# Out:
#   Fabrício CARRaro da alura

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
print(texto.strip().upper().replace("  ", " "))
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
texto = texto.strip().upper().replace("  ", " ")
print(texto)
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
print(texto)
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
nome = input("Digite o seu nome: ")
# Out:
# Digite o seu nome: Fabrício

# %%
print(nome)
# Out:
# Fabrício

# %%
idade = input("Digite a sua idade: ")
# Out:
# Digite a sua idade: 18

# %%
print(idade)
# Out:
# 18

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# str

# %%
idade = int(idade)

# %%
type(idade)
# Out:
# int

# %%
print("A pessoa se chama " + nome + " e tem " + str(idade) + " anos de idade.")
# Out:
# A pessoa se chama Fabrício e tem 18 anos de idade.

# %%
print(f"A pessoa se chama {nome} e tem {idade} anos de idade.")
# Out:
# A pessoa se chama Fabrício e tem 18 anos de idade.

# %% [markdown]
# ### Estruturas Condicionais

# %%
nome = input("Digite o seu nome: ")
# Out:
# Digite o seu nome: Fabrício

# %%
idade = int(input("Digite a sua idade: "))
# Out:
# Digite a sua idade: 18

# %%
type(idade)
# Out:
# int

# %%
if idade >= 18:
    print(f"O {nome} pode entrar na festa porque ele é maior de idade.")
    print(f"Ele tem {idade} anos de idade.")
else:
    print(f"O {nome} NÃO pode entrar na festa porque ele é menor de idade.")
    print(f"Ele tem {idade} anos de idade.")
# Out:
# O Fabrício pode entrar na festa porque ele é maior de idade.
# Ele tem 18 anos de idade.

# %%
media = float(input("Digite a sua média: "))

if media >= 7.0:
    print("Aprovado!")
elif media >= 5.0:
    print("Recuperação!")
else:
    print("Reprovado!")
# Out:
# Digite a sua média: 7.6
# Aprovado!

# %%
media = float(input("Digite a sua média: "))

if media < 5.0:
    print("Reprovado!")
elif media >= 5.0 and media < 7.0:
    print("Recuperação!")
else:
    print("Aprovado!")
# Out:
# Digite a sua média: 5.6
# Recuperação!

# %%
import os

import os

api_key = os.environ.get("Gemini_AP_Key")
if api_key is None:
    api_key = input("Digite a sua Gemini API key: ")

os.environ["GOOGLE_API_KEY"] = api_key

api_key = os.environ.get("Gemini_AP_Key")
if api_key is None:
    api_key = input("Digite a sua Gemini API key: ")

os.environ["GOOGLE_API_KEY"] = api_key

# %%
from google import genai

client = genai.Client()

# %%
import openai

# Seta a chave de API do Gemini_AP
openai.api_key = 'Gemini_AP_Key'

# Define o modelo e a pergunta
model = "gemini-1.5-pro"
question = "O que é a Inteligência Artificial?"

# Gera o conteúdo usando o modelo e a pergunta
response = openai.Completion.create(
    engine=model,
    prompt=question,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Exibe o resultado
print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import openai
#       2
#       3 # Seta a chave de API do Gemini_AP
#       4 openai.api_key = 'Gemini_AP_Key'
#
# ModuleNotFoundError: No module named 'openai'
